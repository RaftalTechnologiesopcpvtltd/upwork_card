# %%
subscription_info =  {
  "application": '',
  "application_fee_percent": '',
  "automatic_tax": {
    "disabled_reason": '',
    "enabled": False,
    "liability": ''
  },
  "billing_cycle_anchor": 1746692714,
  "billing_cycle_anchor_config": '',
  "cancel_at": 1778228714,
  "cancel_at_period_end": True,
  "canceled_at": 1746692720,
  "cancellation_details": {
    "comment": '',
    "feedback": '',
    "reason": "cancellation_requested"
  },
  "collection_method": "charge_automatically",
  "created": 1746692714,
  "currency": "usd",
  "customer": "cus_SGxgunRaw6pXOa",
  "days_until_due": '',
  "default_payment_method": "pm_1RMPlVKyDQNgXXcfa0rCvBM4",
  "default_source": '',
  "default_tax_rates": [],
  "description": '',
  "discounts": [],
  "ended_at": '',
  "id": "sub_1RMPlYKyDQNgXXcfnE70qV0j",
  "invoice_settings": {
    "account_tax_ids": '',
    "issuer": {
      "type": "self"
    }
  },
  "items": {
    "data": [
      {
        "created": 1746692715,
        "current_period_end": 1778228714,
        "current_period_start": 1746692714,
        "discounts": [],
        "id": "si_SGxgtahGU9Bwv9",
        "metadata": {},
        "object": "subscription_item",
        "plan": {
          "active": True,
          "amount": 99900,
          "amount_decimal": "99900",
          "billing_scheme": "per_unit",
          "created": 1739881055,
          "currency": "usd",
          "id": "price_1Qtpk3KyDQNgXXcfzS4EApeg",
          "interval": "year",
          "interval_count": 1,
          "livemode": False,
          "metadata": {},
          "meter": '',
          "nickname": '',
          "object": "plan",
          "product": "prod_RgaeKtKnPvwMvP",
          "tiers_mode": '',
          "transform_usage": '',
          "trial_period_days": '',
          "usage_type": "licensed"
        },
        "price": {
          "active": True,
          "billing_scheme": "per_unit",
          "created": 1739881055,
          "currency": "usd",
          "custom_unit_amount": '',
          "id": "price_1Qtpk3KyDQNgXXcfzS4EApeg",
          "livemode": False,
          "lookup_key": '',
          "metadata": {},
          "nickname": '',
          "object": "price",
          "product": "prod_RgaeKtKnPvwMvP",
          "recurring": {
            "interval": "year",
            "interval_count": 1,
            "meter": '',
            "trial_period_days": '',
            "usage_type": "licensed"
          },
          "tax_behavior": "unspecified",
          "tiers_mode": '',
          "transform_quantity": '',
          "type": "recurring",
          "unit_amount": 99900,
          "unit_amount_decimal": "99900"
        },
        "quantity": 1,
        "subscription": "sub_1RMPlYKyDQNgXXcfnE70qV0j",
        "tax_rates": []
      }
    ],
    "has_more": False,
    "object": "list",
    "total_count": 1,
    "url": "/v1/subscription_items?subscription=sub_1RMPlYKyDQNgXXcfnE70qV0j"
  },
  "latest_invoice": "in_1RMPlYKyDQNgXXcf6KKPYkis",
  "livemode": False,
  "metadata": {},
  "next_pending_invoice_item_invoice": '',
  "object": "subscription",
  "on_behalf_of": '',
  "pause_collection": '',
  "payment_settings": {
    "payment_method_options": {
      "acss_debit": '',
      "bancontact": '',
      "card": {
        "network": '',
        "request_three_d_secure": "automatic"
      },
      "customer_balance": '',
      "konbini": '',
      "sepa_debit": '',
      "us_bank_account": ''
    },
    "payment_method_types": [
      "card"
    ],
    "save_default_payment_method": "off"
  },
  "pending_invoice_item_interval": '',
  "pending_setup_intent": '',
  "pending_update": '',
  "plan": {
    "active": True,
    "amount": 99900,
    "amount_decimal": "99900",
    "billing_scheme": "per_unit",
    "created": 1739881055,
    "currency": "usd",
    "id": "price_1Qtpk3KyDQNgXXcfzS4EApeg",
    "interval": "year",
    "interval_count": 1,
    "livemode": False,
    "metadata": {},
    "meter": '',
    "nickname": '',
    "object": "plan",
    "product": "prod_RgaeKtKnPvwMvP",
    "tiers_mode": '',
    "transform_usage": '',
    "trial_period_days": '',
    "usage_type": "licensed"
  },
  "quantity": 1,
  "schedule": '',
  "start_date": 1746692714,
  "status": "active",
  "test_clock": '',
  "transfer_data": '',
  "trial_end": '',
  "trial_settings": {
    "end_behavior": {
      "missing_payment_method": "create_invoice"
    }
  },
  "trial_start": ''
}

# %%
subscription_info['items']['data'][0]['current_period_start']
from datetime import datetime


datetime.fromtimestamp(int(subscription_info['items']['data'][0]['current_period_start']))
# Out:
# datetime.datetime(2025, 5, 8, 13, 55, 14)
